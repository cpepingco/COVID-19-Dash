# %% [markdown]
# # Data Preprocessing

# %%
#import packages
import pandas as pd
import numpy as np 

#Read datasets from CSSE github repo
confirmed = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')
deaths = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv')
recoveries = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv')

# %%
#view the first 5 rows of each data frame
confirmed.head(5)
#print(deaths.head(5))
#print(recoveries.head(5))
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  8/10/21  8/11/21  8/12/21  \
# 0        0        0        0        0  ...   151013   151291   151563
# 1        0        0        0        0  ...   134201   134487   134761
# 2        0        0        0        0  ...   183347   184191   185042
# 3        0        0        0        0  ...    14873    14891    14908
# 4        0        0        0        0  ...    43890    43998    44174
#
#    8/13/21  8/14/21  8/15/21  8/16/21  8/17/21  8/18/21  8/19/21
# 0   151770   151770   151770   152142   152243   152363   152411
# 1   135140   135550   135947   136147   136598   137075   137597
# 2   185902   186655   187258   187968   188663   189384   190078
# 3    14924    14924    14924    14954    14960    14976    14981
# 4    44328    44534    44617    44739    44972    45175    45325
#
# [5 rows x 580 columns]

# %% [markdown]
# Data sources from CSSE are in wide format. To better analyze data, we need to transform from wide to long.

# %%
# Transform wide format to long format
confirmed = pd.melt(confirmed, id_vars=confirmed.columns[:4], value_vars = confirmed.columns[4:], var_name = 'date', value_name = 'confirmed')
deaths = pd.melt(deaths, id_vars=deaths.columns[:4], value_vars = deaths.columns[4:], var_name = 'date', value_name = 'deaths')
recoveries = pd.melt(recoveries, id_vars=recoveries.columns[:4], value_vars = recoveries.columns[4:], var_name = 'date', value_name = 'recoveries')

# %%
#view the first 5 rows of each data frame
confirmed.head(5)
#print(deaths.head(5))
#print(recoveries.head(5))
# Out:
#   Province/State Country/Region       Lat       Long     date  confirmed
# 0            NaN    Afghanistan  33.93911  67.709953  1/22/20          0
# 1            NaN        Albania  41.15330  20.168300  1/22/20          0
# 2            NaN        Algeria  28.03390   1.659600  1/22/20          0
# 3            NaN        Andorra  42.50630   1.521800  1/22/20          0
# 4            NaN         Angola -11.20270  17.873900  1/22/20          0

# %% [markdown]
# ## Group the Provinces/State into their Respective Countries

# %% [markdown]
# ### Canada

# %% [markdown]
# The confirmed & deaths tables present Canada data by Province/State while the recoveries table only displays the total number of cases in the whole country. This conflict will need to addressed first before combining the tables to gether as unmatched join keys will be omitted.

# %%
#Summarize confirmed and deaths data by date
confirmed_canada = confirmed[confirmed['Country/Region'] == 'Canada'].groupby('date').sum()[['confirmed']]
deaths_canada = deaths[deaths['Country/Region'] == 'Canada'].groupby('date').sum()[['deaths']]
 
confirmed_canada.head()
# Out:
#          confirmed
# date
# 1/1/21      591149
# 1/10/21     666375
# 1/11/21     674624
# 1/12/21     681015
# 1/13/21     688097

# %%
#Extract columns from recoveries table
recoveries_canada = recoveries[recoveries['Country/Region'] == 'Canada']
canada_template = recoveries_canada[recoveries_canada.columns[:-1]].reset_index(drop=True)  
canada_template.head()
# Out:
#   Province/State Country/Region      Lat      Long     date
# 0            NaN         Canada  56.1304 -106.3468  1/22/20
# 1            NaN         Canada  56.1304 -106.3468  1/23/20
# 2            NaN         Canada  56.1304 -106.3468  1/24/20
# 3            NaN         Canada  56.1304 -106.3468  1/25/20
# 4            NaN         Canada  56.1304 -106.3468  1/26/20

# %% [markdown]
# reset_index() is a method to reset the index of a data frame.
#
# Syntax: DataFrame.reset_index(level=None, drop=False, inplace=False, col_level=0, col_fill="")
#
# drop: Boolean value, adds the replaced index column to the data if False

# %% [markdown]
# ## Combining Tables

# %%
#Join aggregated confirmed and deaths data with extracted columns
confirmed_canada = canada_template.merge(confirmed_canada, how='inner', left_on='date', right_index=True)
deaths_canada = canada_template.merge(deaths_canada, how='inner', left_on='date', right_index=True)
confirmed_canada.head()
# Out:
#   Province/State Country/Region      Lat      Long     date  confirmed
# 0            NaN         Canada  56.1304 -106.3468  1/22/20          0
# 1            NaN         Canada  56.1304 -106.3468  1/23/20          0
# 2            NaN         Canada  56.1304 -106.3468  1/24/20          0
# 3            NaN         Canada  56.1304 -106.3468  1/25/20          0
# 4            NaN         Canada  56.1304 -106.3468  1/26/20          1

# %% [markdown]
# The left dataframe is canada_template, the right dataframe is confirmed_canada
#
# left_on: label or list, or array-like
# * Column or index level names to join on in the left DataFrame.
#
# right_index: bool, default False
# * Use the index from the right DataFrame as the join key. Same caveats as left_index

# %%
#Add the aggregated data for Canada back to confirmed and deaths table
confirmed = confirmed[confirmed['Country/Region'] != 'Canada'].append(confirmed_canada)  #selected df without Canada
deaths = deaths[deaths['Country/Region'] != 'Canada'].append(deaths_canada)

confirmed.head()
# Out:
#   Province/State Country/Region       Lat       Long     date  confirmed
# 0            NaN    Afghanistan  33.93911  67.709953  1/22/20          0
# 1            NaN        Albania  41.15330  20.168300  1/22/20          0
# 2            NaN        Algeria  28.03390   1.659600  1/22/20          0
# 3            NaN        Andorra  42.50630   1.521800  1/22/20          0
# 4            NaN         Angola -11.20270  17.873900  1/22/20          0

# %%
#Join confirmed, deaths and recoveries data together
data = confirmed.merge(deaths, how='inner', on=['Country/Region', 'Province/State','date']).merge(recoveries,how = 'inner', on =['Country/Region', 'Province/State','date'])
data['recoveries'] = data['recoveries'].astype(int)
#rearrange columns
data = data[['Province/State', 'Country/Region', 'date', 'Lat', 'Long', 'confirmed', 'deaths', 'recoveries']]
data.sample(5)
# Out:
#        Province/State Country/Region     date      Lat       Long  confirmed  \
# 2453    Faroe Islands        Denmark  1/31/20  61.8926  -6.911800          0
# 102743            NaN        Morocco  2/15/21  31.7917  -7.092600     478595
# 92533             NaN    South Sudan   1/7/21   6.8770  31.307000       3589
# 19959             NaN           Togo   4/6/20   8.6195   0.824800         58
# 98469         Mayotte         France  1/30/21 -12.8275  45.166244       8231
#
#         deaths  recoveries
# 2453         0           0
# 102743    8491      459549
# 92533       63        3131
# 19959        3          23
# 98469       61        2964

# %% [markdown]
# ## Population Data
# One metric used in the Covid-19 dashboard is infection rate: $confirmed / population$. Countries' population is not available in the CSSE dataset so we will need to combine with another source.
#
# Source: [Tanu N Prabhu](https://www.kaggle.com/tanuprabhu/population-by-country-2020)
#
# One very common problems when combining different data sources is unmatched value names.

# %%
#Read dataset
population = pd.read_csv('https://raw.githubusercontent.com/cpepingco/COVID-19-Dash-/main/population_by_country_2020.csv')
population.sample(5)
# Out:
#     Country (or dependency)  Population (2020) Yearly Change  Net Change  \
# 62                    Chile           19144605        0.87 %      164163
# 102            Sierra Leone            8004158        2.10 %      163768
# 213                  Monaco              39290        0.71 %         278
# 150                  Latvia            1882408       -1.08 %      -20545
# 190                    Guam             169031        0.89 %        1481
#
#      Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# 62                26           743532        111708.0        1.7       35
# 102              111            72180         -4200.0        4.3       19
# 213            26337                1             NaN       N.A.     N.A.
# 150               30            62200        -14837.0        1.7       44
# 190              313              540          -506.0        2.3       31
#
#     Urban Pop % World Share
# 62         85 %      0.25 %
# 102        43 %      0.10 %
# 213        N.A.      0.00 %
# 150        69 %      0.02 %
# 190        95 %      0.00 %

# %%
for c in data['Country/Region'].unique():
    if c not in population['Country (or dependency)'].unique():
        print(c)
# Out:
# Burma
# Congo (Brazzaville)
# Congo (Kinshasa)
# Cote d'Ivoire
# Czechia
# Diamond Princess
# Korea, South
# Kosovo
# MS Zaandam
# Saint Kitts and Nevis
# Saint Vincent and the Grenadines
# Sao Tome and Principe
# Summer Olympics 2020
# Taiwan*
# US
# West Bank and Gaza

# %% [markdown]
# A few of the countries have to be manually replaced.

# %%
country_mapper = {
   # 'Congo (Brazzaville)': 'Congo',
   # 'Congo (Kinshasa)': 'Congo',
    "Cote d'Ivoire": "Côte d'Ivoire",
    'Czechia': 'Czech Republic (Czechia)',
    'Korea, South': 'South Korea',
    'Saint Vincent and the Grenadines': 'St. Vincent & Grenadines',
    'Taiwan*': 'Taiwan',
    'US': 'United States',
    'West Bank and Gaza': 'Israel',
    'Saint Kitts and Nevis': 'Saint Kitts & Nevis',
    'Burma': 'Myanmar',
    'Sao Tome and Principe': 'Sao Tome & Principe'
}

data['Country/Region'] = data['Country/Region'].replace(country_mapper)
#data.index = data['Country/Region']
data.sample(10)
# Out:
#        Province/State            Country/Region      date        Lat  \
# 66095             NaN                   Croatia   9/29/20  45.100000
# 118387            NaN                  Cambodia   4/16/21  11.550000
# 71385       St Martin                    France  10/19/20  18.070800
# 125945            NaN                  Tanzania   5/14/21  -6.369028
# 60329             NaN                   Finland    9/7/20  61.924110
# 120923            NaN                     Samoa   4/25/21 -13.759000
# 24107             NaN                Mozambique   4/22/20 -18.665700
# 103580            NaN                     Spain   2/18/21  40.463667
# 44006             NaN  Czech Republic (Czechia)    7/7/20  49.817500
# 102359   Heilongjiang                     China   2/14/21  47.862000
#
#               Long  confirmed  deaths  recoveries
# 66095    15.200000      16380     275       14947
# 118387  104.916700       5480      38        2393
# 71385   -63.050100        531       8         380
# 125945   34.888822        509      21         183
# 60329    25.748151       8327     336        7350
# 120923 -172.104600          3       0           2
# 24107    35.529600         41       0           8
# 103580   -3.749220    3121687   66704      150376
# 44006    15.473000      12685     351        7910
# 102359  127.761500       1609      13        1504

# %% [markdown]
# ### China Problem

# %%
#Group China by Country/Region and date
china_template = data[(data['Country/Region'] == 'China')]
china_template['Province/State'] = np.nan
china_template = china_template.groupby(['date','Country/Region']).sum()   #ignore lat and long because it is wrong
china_template.reset_index(inplace = True)
china_template[['Province/State', 'Country/Region', 'date', 'Lat', 'Long', 'confirmed', 'deaths', 'recoveries']]
china_template['Province/State'] = np.nan
china_template.head()
# Out:
# <ipython-input-14-5be1615dd7ba>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   china_template['Province/State'] = np.nan
#       date Country/Region  Province/State        Lat       Long  confirmed  \
# 0   1/1/21          China             NaN  1079.6253  3686.4211      96023
# 1  1/10/21          China             NaN  1079.6253  3686.4211      96824
# 2  1/11/21          China             NaN  1079.6253  3686.4211      96920
# 3  1/12/21          China             NaN  1079.6253  3686.4211      97095
# 4  1/13/21          China             NaN  1079.6253  3686.4211      97275
#
#    deaths  recoveries
# 0    4782       90031
# 1    4792       90697
# 2    4793       90772
# 3    4794       90857
# 4    4796       90953

# %%
#add the china data back into the original df
data = pd.concat([data, china_template], ignore_index = True)
data.tail(10)
# Out:
#        Province/State Country/Region     date        Lat       Long  \
# 152630            NaN          China  9/28/20  1079.6253  3686.4211
# 152631            NaN          China  9/29/20  1079.6253  3686.4211
# 152632            NaN          China   9/3/20  1079.6253  3686.4211
# 152633            NaN          China  9/30/20  1079.6253  3686.4211
# 152634            NaN          China   9/4/20  1079.6253  3686.4211
# 152635            NaN          China   9/5/20  1079.6253  3686.4211
# 152636            NaN          China   9/6/20  1079.6253  3686.4211
# 152637            NaN          China   9/7/20  1079.6253  3686.4211
# 152638            NaN          China   9/8/20  1079.6253  3686.4211
# 152639            NaN          China   9/9/20  1079.6253  3686.4211
#
#         confirmed  deaths  recoveries
# 152630      90505    4739       85398
# 152631      90528    4739       85423
# 152632      89986    4728       84737
# 152633      90545    4739       85460
# 152634      90008    4728       84782
# 152635      90025    4728       84837
# 152636      90058    4730       84873
# 152637      90078    4732       84900
# 152638      90087    4733       84932
# 152639      90100    4733       84957

# %% [markdown]
# ### UK Problem

# %%
#Group UK by Country/Region and date
UK_template = data[(data['Country/Region'] == 'United Kingdom')]
UK_template['Province/State'] = np.nan
UK_template = UK_template.groupby(['date','Country/Region']).sum()   #ignore lat and long because it is wrong
UK_template.reset_index(inplace = True)
UK_template[['Province/State', 'Country/Region', 'date', 'Lat', 'Long', 'confirmed', 'deaths', 'recoveries']]
UK_template['Province/State'] = np.nan
UK_template.head()
# Out:
# <ipython-input-16-e8c7d856e6f8>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   UK_template['Province/State'] = np.nan
#       date  Country/Region  Province/State         Lat        Long  confirmed  \
# 0   1/1/21  United Kingdom             NaN  262.083198 -497.280566    2549693
# 1  1/10/21  United Kingdom             NaN  262.083198 -497.280566    3081372
# 2  1/11/21  United Kingdom             NaN  262.083198 -497.280566    3127647
# 3  1/12/21  United Kingdom             NaN  262.083198 -497.280566    3173295
# 4  1/13/21  United Kingdom             NaN  262.083198 -497.280566    3220957
#
#    deaths  recoveries
# 0   74237        5682
# 1   81567        7013
# 2   82096        7153
# 3   83342        7352
# 4   84910        7434

# %%
#add UK back to original df
data = pd.concat([data, UK_template], ignore_index = True)
data.tail(10)
# Out:
#        Province/State  Country/Region     date         Lat        Long  \
# 153206            NaN  United Kingdom  9/28/20  262.083198 -497.280566
# 153207            NaN  United Kingdom  9/29/20  262.083198 -497.280566
# 153208            NaN  United Kingdom   9/3/20  262.083198 -497.280566
# 153209            NaN  United Kingdom  9/30/20  262.083198 -497.280566
# 153210            NaN  United Kingdom   9/4/20  262.083198 -497.280566
# 153211            NaN  United Kingdom   9/5/20  262.083198 -497.280566
# 153212            NaN  United Kingdom   9/6/20  262.083198 -497.280566
# 153213            NaN  United Kingdom   9/7/20  262.083198 -497.280566
# 153214            NaN  United Kingdom   9/8/20  262.083198 -497.280566
# 153215            NaN  United Kingdom   9/9/20  262.083198 -497.280566
#
#         confirmed  deaths  recoveries
# 153206     441575   42090        2354
# 153207     448731   42162        2370
# 153208     342708   41616        1750
# 153209     455848   42233        2375
# 153210     344686   41626        1756
# 153211     346513   41638        1806
# 153212     349500   41640        1824
# 153213     352453   41643        1824
# 153214     354934   41675        1827
# 153215     357615   41683        1833

# %% [markdown]
# ### Australia Problem

# %%
#Group UK by Country/Region and date
Australia_template = data[(data['Country/Region'] == 'Australia')]
Australia_template['Province/State'] = np.nan
#Australia_template = Australia_template.loc[Australia_template['Province/State'].isna()]
Australia_template = Australia_template.groupby(['date','Country/Region']).sum()   #ignore lat and long because it is wrong
Australia_template.reset_index(inplace = True)
Australia_template[['Province/State', 'Country/Region', 'date', 'Lat', 'Long', 'confirmed', 'deaths', 'recoveries']]
Australia_template['Province/State'] = np.nan
Australia_template.head()
# Out:
# <ipython-input-18-e451eeee0895>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Australia_template['Province/State'] = np.nan
#       date Country/Region  Province/State       Lat       Long  confirmed  \
# 0   1/1/21      Australia             NaN -256.8502  1130.8439      28460
# 1  1/10/21      Australia             NaN -256.8502  1130.8439      28614
# 2  1/11/21      Australia             NaN -256.8502  1130.8439      28634
# 3  1/12/21      Australia             NaN -256.8502  1130.8439      28650
# 4  1/13/21      Australia             NaN -256.8502  1130.8439      28660
#
#    deaths  recoveries
# 0     909       22573
# 1     909       22621
# 2     909       22627
# 3     909       22643
# 4     909       22650

# %%
#add Australia back to original df
data = pd.concat([data, Australia_template], ignore_index = True)
data.tail(10)
# Out:
#        Province/State Country/Region     date       Lat       Long  confirmed  \
# 153782            NaN      Australia  9/28/20 -256.8502  1130.8439      27055
# 153783            NaN      Australia  9/29/20 -256.8502  1130.8439      27078
# 153784            NaN      Australia   9/3/20 -256.8502  1130.8439      26136
# 153785            NaN      Australia  9/30/20 -256.8502  1130.8439      27096
# 153786            NaN      Australia   9/4/20 -256.8502  1130.8439      26207
# 153787            NaN      Australia   9/5/20 -256.8502  1130.8439      26278
# 153788            NaN      Australia   9/6/20 -256.8502  1130.8439      26321
# 153789            NaN      Australia   9/7/20 -256.8502  1130.8439      26373
# 153790            NaN      Australia   9/8/20 -256.8502  1130.8439      26465
# 153791            NaN      Australia   9/9/20 -256.8502  1130.8439      26524
#
#         deaths  recoveries
# 153782     882       21558
# 153783     886       21623
# 153784     737       18920
# 153785     888       21655
# 153786     748       19178
# 153787     753       19336
# 153788     762       19473
# 153789     770       19610
# 153790     781       19731
# 153791     788       19869

# %%
data.to_csv('covid19.csv')
